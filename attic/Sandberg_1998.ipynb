# %%
import pandas as pd

# Define the partial data structure based on the document
partial_data = {
    "Amino Acid": ["Ala", "Arg", "Asn", "Asp", "Cys", "Gln", "Glu", "Gly", "His", "Ile", "Leu", "Lys", "Met", "Phe", "Pro", "Ser", "Thr", "Trp", "Tyr", "Val"],
    "MW": [89.1, 174.2, 132.1, 133.1, 121.2, 146.1, 147.1, 75.1, 155.2, 131.2, 131.2, 146.2, 149.2, 165.2, 115.1, 105.1, 119.1, 204.2, 181.2, 117.2],
    "TLI": [60, 1, 39, 66, 35, 53, 74, 44, 9, 80, 82, 1, 77, 82, 52, 44, 58, 86, 81, 74],
    "TL2": [9, 1, 5, 2, 40, 7, 4, 6, 1, 28, 33, 1, 29, 35, 11, 6, 11, 40, 32, 22],
    "TL3": [52, 19, 21, 38, 46, 32, 42, 32, 16, 72, 73, 19, 63, 66, 57, 36, 46, 49, 68, 68],
    "vdW": [13.7, 64.9, 32.5, 30.0, 25.0, 42.7, 40.2, 3.5, 45.1, 44.4, 44.4, 51.1, 45.0, 56.1, 30.7, 18.3, 28.5, 75.1, 61.6, 34.1]
}

# Creating a DataFrame
partial_df = pd.DataFrame(partial_data)

# %%
amino_acid = [
    "Ala", "Arg", "Asn", "Asp", "Cys", "Gln", "Glu", "Gly", "His", "Ile", "Leu", "Lys", "Met", "Phe", "Pro", "Ser", "Thr", "Trp", "Tyr", "Val",
    "Acpa", "Aecys", "Afa", "Aiba", "Aile", "Alg", "Aba", "Aphe", "Bal", "Brphe", "Cha", "Cit", "Clala", "Cle", "Clphe", "Cya", "Dab", "Dap",
    "Dhp", "Dhphe", "Fphe", "Gaa", "Hag", "Hlys", "Hnvl", "Hog", "Hoph", "Hos", "Hpr", "Iphe", "Ise", "MIe", "Msmet", "INala", "2Nala", "Ne",
    "NmAla", "Nva", "Obser", "ObTyr", "OeTyr", "Omser", "OmThr", "OmTyr", "Orn", "Pen", "Pga", "Pip", "Sar", "Tfa", "ThPhe", "Vig", "Aaspa",
    "Ahdna", "Ahoha", "Ahsopa", "Ahspa", "Ahtda", "Dadna", "Datda", "Dfni", "Dfnv", "Dtca", "Hfnl", "PfHl", "Pfnv", "Tca"
]

# %%
Ala = [89.1, 60, 24, 29, 9, 52, 23, 37, 13.7, 4.13, 3.77 3.30 -3.12 -10.09 1.15 -92.6 5.34 4.47 5.62 133 76 58]
Arg = [174.2, 1, 9, 6, 1, 19, 7, 1, 64.9 , 4.06, 3.76 3.20 -4.79 -9.64 1.03 -72.3 11.85 4.31 5.33 221 132 90]
Asn = [132.1, 39, 14, 25, 5, 21, 12, 12, 32.5, 4.33, 4.00 3.56 -3.73 -10.43 0.68 -132.4 7.72 4.87 5.56 160 121 39]
Asp = [133.1, 66, 16, 9, 2, 38, 20, 19, 30.0, 4.34, 3.89 3.51 -2.43 -10.35 0.71 -182.3 7.25 4.82 5.53 158 118 41]
Cys = [121.2, 35, 23, 27, 40, 46, 63, 81, 25.0, 4.30, 3.97 3.00 -2.35 -9.51 0.27 -86.5 7.07 4.62 4.89 150 74 76]
