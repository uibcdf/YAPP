# %%
import yapp as yapp

# %%
cpps = []

for ii in yapp.databases.AiCPP.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.BChemRF_CPPred.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.C2Pred.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.CellPPD.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.CPPSite2.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.CSM_peptides.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.Dobchev.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.Hallbrink.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.Hansen.cpps:
    if ii not in cpps:
        cpps.append(ii)

for ii in yapp.databases.ITP_Pred.cpps:
    if ii not in cpps:
        cpps.append(ii)

# %%
len(cpps)
# Out:
# 1582

# %%
fff=open('all_cpps.txt', 'w')

# %%
for ii in cpps:
    fff.write(ii+"\n")

# %%
fff.close()
