# %%
path_dbs = 'yapp/data/DBs'

# %%
cpps = []
no_cpps = []

# C2Pred
db = 'C2Pred'

filename = path_dbs+'/'+db+'/all_cpps.txt'
with open(filename, 'r') as fff:
    for line in fff:
        cpps.append(line.strip())


filename = path_dbs+'/'+db+'/all_noncpps.txt'
with open(filename, 'r') as fff:
    for line in fff:
        non_cpps.append(line.strip())

# %%
len(no_cpps)

# %%
import yapp as yapp

# %%
yapp.databases.BChemRF_CPPred.no_cpps

# %%
import yapp as yapp

# %%
yapp.databases.C2Pred.cpps
# Out:
# ['AAVLLPVLLAAP',
#  'AHALCLTERQIKIWFQNRRMKWKKEN',
#  'CGPGSDDEAAADAQHAAPPKKKRKVGY',
#  'CNGRCGGKKLKLLKLL',
#  'CNGRCGGLVTT',
#  'GALFLGFLGAAGSTMGAWSQPKSKRKV',
#  'GIGKFLHSAKKWGKAFVGQIMNC',
#  'GWTLNPAGYLLGKINLKALAALAKKIL',
#  'KALAALLKKWAKLLAALK',
#  'KCRKKKRRQRRRKKLSECLKRIGDELDS',
#  'KCRKKKRRQRRRKKPVVHLTLRQAGDDFSR',
#  'KETWWETWWTEWSQPKKKRKV',
#  'KITLKLAIKAWKLALKAA',
#  'KLAAALLKKWKKLAAALL',
#  'KLALQLALQALQAALQLA',
#  'KRPAATKKAGQAKKKKL',
#  'LGTYTQDFNKFHTFPQTAIGVGAP',
#  'LKTLATALTKLAKTLTTL',
#  'LKTLTETLKELTKTLTEL',
#  'MANLGYWLLALFVTMWTDVGLCKKRPKP',
#  'MPKKKPTPIQLNP',
#  'MVKSKIGSWILVLFVAMWSDVGLCKKRPKP',
#  'PKKKRKVALWKTLLKKVLKA',
#  'RGGRLSSYSRRRFSTSTGR',
#  'RKSSKPIMEKRRRAR',
#  'RQARRNRRRALWKTLLKKVLKA',
#  'RQGAARVTSWLGRQLRIAGKRLEGRSK',
#  'RQIKIWFQNRRMKWKKLRKKKKKH',
#  'RQPKIWFPNRRMPWKK',
#  'RRWRRWWRRWWRRWRR',
#  'RVIRVWFQNKRCKDKK',
#  'TRRNKRNRIQEQLNRK',
#  'TRSSRAGLQWPVGRVHRLLRKGGC',
#  'VQAILRRNWNQYKIQ',
#  'VRLPPPVRLPPPVRLPPP',
#  'YGRKKRRQRRRGTSSSSDELSWIIELLEK',
# ...
