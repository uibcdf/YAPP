# %%
import yapp as yapp

# %%
non_cpps = []

for ii in yapp.databases.AiCPP.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.BChemRF_CPPred.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.C2Pred.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.CellPPD.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

#for ii in yapp.databases.CPPSite2.non_cpps:
#    if ii not in non_cpps:
#        non_cpps.append(ii)

for ii in yapp.databases.CSM_peptides.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.Dobchev.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.Hallbrink.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.Hansen.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

for ii in yapp.databases.ITP_Pred.non_cpps:
    if ii not in non_cpps:
        non_cpps.append(ii)

# %%
len(non_cpps)
# Out:
# 4369

# %%
fff=open('all_non_cpps.txt', 'w')

# %%
for ii in non_cpps:
    fff.write(ii+"\n")

# %%
fff.close()
